# %% [markdown]
# # Collections
#
# - set
# - uple
# - list
# - dict (dictionary)

# %%
# set
# mutable, unorder (no index), no duplicates, iterable

set_inferred = {1,2,3,2} # we almost never do this
set_explicit = set([2,3,4,4])

print(f"set inferred = {set_inferred}")
print(f"set explicit = {set_explicit}")
# Out:
# set inferred = {1, 2, 3}
# set explicit = {2, 3, 4}

# %%
set_inferred.add(7) # add
print(f"add = {set_inferred}")
set_inferred.remove(3) # remove
print(f"remove 3 set inferred = {set_inferred}")
diff = set_inferred.difference(set_explicit) # get difference between sets
print(f"difference = {diff}")
overlap = set_inferred.intersection(set_explicit) # get overlaps between sets
print(f"overlap = {overlap}")
# Out:
# add = {1, 2, 3, 7}
# remove 3 set inferred = {1, 2, 7}
# difference = {1, 7}
# overlap = {2}

# %%
# tuple
# immutable, ordered(index), duplicates, iterable
tuple_inferred = (1,2,3,3,5,6)
tuple_explicit = ([4,5,6,7,2])

print(f"tuple inferred = {tuple_inferred}")
print(f"tuple explicit = {tuple_explicit}")
# Out:
# tuple inferred = (1, 2, 3, 3, 5, 6)
# tuple explicit = [4, 5, 6, 7, 2]

# %%
#index notation
#[start : stop : step]
print(f"index 0 = {tuple_inferred[0]}")
print(f"tuple inferred has {len(tuple_inferred)} elements")
print(f"last item = {tuple_inferred[-1]}")
print(f"get 2nd and 3rd items = {tuple_inferred[1:3]}")
print(f"all but last three = {tuple_inferred[:-3]}")
# Out:
# index 0 = 1
# tuple inferred has 6 elements
# last item = 6
# get 2nd and 3rd items = (2, 3)
# all but last three = (1, 2, 3)

# %%
#tuple methods
count = tuple_inferred.count(3) #get number of value
print(count)
idx = tuple_inferred.index(5)
print(idx)
# Out:
# 2
# 4

# %%
#list
#mutable, ordered (index), duplicates, iterable
list_inferred = [1,2,3,4,5,5,6,3]
list_explicit = list((4,5,6,1,1,3,2))

print(f"list inferred = {list_inferred}")
print(f"list explicit = {list_explicit}")
# Out:
# list inferred = [1, 2, 3, 4, 5, 5, 6, 3]
# list explicit = [4, 5, 6, 1, 1, 3, 2]

# %%
#list methods
list_inferred.append(7) #add
print(f"append 7 = {list_inferred}")

list_inferred.remove(7) #remove
print(f"remove = {list_inferred}")

removed = list_inferred.pop()
print(f"after pop = {list_inferred}")
# Out:
# append 7 = [1, 2, 3, 4, 5, 5, 6, 3, 7]
# remove = [1, 2, 3, 4, 5, 5, 6, 3]
# after pop = [1, 2, 3, 4, 5, 5, 6]

# %%
#changing
list_inferred[0] = "Awesome index"
list_inferred
# Out:
# ['Awesome index', 2, 3, 4, 5, 5, 6]

# %%
# dict (dictionary)
#mutable, {key : value}, unordered (index by key), no duplicate keys but duplicate values, iterable

dict_inferred = {
    "name" : "John",
    "age" : 30,
    
}

dict_explicit = dict(city= "New York", country = "USA")

print(f"dict inferred = {dict_inferred}")
print(f"dict explicit = {dict_explicit}")
# Out:
# dict inferred = {'name': 'John', 'age': 30}
# dict explicit = {'city': 'New York', 'country': 'USA'}

# %%
dict_inferred["age"]
# Out:
# 30

# %%
dict_inferred["gender"] = "m"
dict_inferred
# Out:
# {'name': 'John', 'age': 30, 'gender': 'm'}

# %%
dict_inferred["age"] = 72
dict_inferred
# Out:
# {'name': 'John', 'age': 72, 'gender': 'm'}
